# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("MLAnalysisAdClicks").getOrCreate()
sc = spark.sparkContext
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/ext3/spark-3.1.2-bin-hadoop3.2/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 24/04/22 13:08:06 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# Load normalized data
df = spark.read.option("delimiter", "\t") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("/home/bw2298/combined_training_before_normalize.txt")

# Select necessary columns and cast them as needed
from pyspark.sql.functions import col

df = df.select(
    col("numClick").cast("int"),
    col("region").cast("int"),
    col("city").cast("int"),
    col("adExchange").cast("int"),
    col("width").cast("int"),
    col("height").cast("int"),
    col("floorPrice").cast("int"),
    col("weekday"),
    col("hour").cast("int")
)

# Check the data
df.show(5)
# Out:
# +--------+------+----+----------+-----+------+----------+-------+----+
# |numClick|region|city|adExchange|width|height|floorPrice|weekday|hour|
# +--------+------+----+----------+-----+------+----------+-------+----+
# |       0|    94| 100|         2|  468|    60|        13| Monday|   0|
# |       0|    40|  42|         2|  728|    90|         5| Monday|   0|
# |       0|    40|  45|         1|  160|   600|         0| Monday|   0|
# |       0|    80|  85|         2|  300|   250|         5| Monday|   0|
# |       0|     0|   0|         2|  300|   250|         5| Monday|   0|
# +--------+------+----+----------+-----+------+----------+-------+----+
# only showing top 5 rows

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler

# Indexing and encoding categorical columns
categoricalColumns = ['region', 'city', 'adExchange', 'weekday']
stages = []

for categoricalCol in categoricalColumns:
    stringIndexer = StringIndexer(inputCol=categoricalCol, outputCol=categoricalCol + "Index")
    encoder = OneHotEncoder(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
    stages += [stringIndexer, encoder]

# Assembling vector
assemblerInputs = [c + "classVec" for c in categoricalColumns] + ['width', 'height', 'floorPrice', 'hour']
assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
stages += [assembler]

# %%
from pyspark.ml import Pipeline
from pyspark.ml.classification import LogisticRegression, GBTClassifier, LinearSVC
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# Set up the evaluator
evaluator = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", labelCol="numClick", metricName="areaUnderROC")

# Logistic Regression
lr = LogisticRegression(labelCol="numClick", featuresCol="features", maxIter=10)
pipeline_lr = Pipeline(stages=stages + [lr])
model_lr = pipeline_lr.fit(df)
predictions_lr = model_lr.transform(df)
print("Logistic Regression AUC: ", evaluator.evaluate(predictions_lr))
# Out:
# 24/04/22 13:15:57 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
# 24/04/22 13:15:57 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
# 24/04/22 13:15:57 WARN MemoryStore: Not enough space to cache rdd_63_12 in memory! (computed 31.2 MiB so far)
# 24/04/22 13:15:57 WARN BlockManager: Persisting block rdd_63_12 to disk instead.
# 24/04/22 13:15:57 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 30.0 MiB so far)
# 24/04/22 13:15:57 WARN BlockManager: Persisting block rdd_63_8 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_11 in memory! (computed 30.9 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_11 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_7 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_7 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_6 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_4 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_1 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_1 to disk instead.
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:15:58 WARN MemoryStore: Not enough space to cache rdd_63_5 in memory! (computed 32.0 MiB so far)
# 24/04/22 13:15:58 WARN BlockManager: Persisting block rdd_63_5 to disk instead.
# 24/04/22 13:16:01 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:01 WARN BlockManager: Persisting block rdd_63_17 to disk instead.
# 24/04/22 13:16:01 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:01 WARN BlockManager: Persisting block rdd_63_16 to disk instead.
# 24/04/22 13:16:01 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:01 WARN BlockManager: Persisting block rdd_63_20 to disk instead.
# 24/04/22 13:16:01 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:01 WARN BlockManager: Persisting block rdd_63_18 to disk instead.
# 24/04/22 13:16:01 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_63_16 in memory.
# 24/04/22 13:16:03 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 384.0 B so far)
# 24/04/22 13:16:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_63_17 in memory.
# 24/04/22 13:16:03 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 384.0 B so far)
# 24/04/22 13:16:03 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:16:03 WARN BlockManager: Persisting block rdd_63_19 to disk instead.
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_63_18 in memory.
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 384.0 B so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:04 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:05 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:06 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:07 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:08 WARN MemoryStore: Not enough space to cache rdd_63_8 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:09 WARN MemoryStore: Not enough space to cache rdd_63_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:09 WARN MemoryStore: Not enough space to cache rdd_63_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:09 WARN MemoryStore: Not enough space to cache rdd_63_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:09 WARN MemoryStore: Not enough space to cache rdd_63_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:16:09 WARN MemoryStore: Not enough space to cache rdd_63_20 in memory! (computed 17.0 MiB so far)
# Logistic Regression AUC:  0.6114053567631033

# %%
# Gradient Boosting Trees
gbt = GBTClassifier(labelCol="numClick", featuresCol="features", maxIter=10)
pipeline_gbt = Pipeline(stages=stages + [gbt])
model_gbt = pipeline_gbt.fit(df)
predictions_gbt = model_gbt.transform(df)
print("Gradient Boosting AUC: ", evaluator.evaluate(predictions_gbt))
# Out:
# 24/04/22 13:17:51 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:17:51 WARN BlockManager: Persisting block rdd_203_8 to disk instead.
# 24/04/22 13:17:51 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:17:51 WARN BlockManager: Persisting block rdd_203_6 to disk instead.
# 24/04/22 13:17:51 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:51 WARN BlockManager: Persisting block rdd_203_1 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_14 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_0 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_3 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_12 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_9 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_15 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_13 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_11 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_2 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_10 to disk instead.
# 24/04/22 13:17:52 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:17:52 WARN BlockManager: Persisting block rdd_203_4 to disk instead.
# 24/04/22 13:17:53 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:17:53 WARN BlockManager: Persisting block rdd_203_7 to disk instead.
# 24/04/22 13:17:56 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 357.9 MiB so far)
# 24/04/22 13:17:56 WARN BlockManager: Persisting block rdd_203_5 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 2.3 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_3 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 5.6 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_8 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_3 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_11 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_11 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_11 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_10 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_10 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_10 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_8 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_8 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_15 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_15 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_15 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_3 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_3 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_13 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_6 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_13 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_6 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_6 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_6 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_14 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_14 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_13 to disk instead.
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_14 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_0 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_0 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_0 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_0 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_12 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_12 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_12 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_9 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_9 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_9 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_9 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_5 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_5 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_5 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_2 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_2 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_2 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_2 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_1 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_1 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_1 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_1 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_7 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_7 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_7 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_7 to disk instead.
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_4 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_4 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_4 in memory.
# 24/04/22 13:17:59 WARN MemoryStore: Not enough space to cache rdd_205_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:17:59 WARN BlockManager: Persisting block rdd_205_4 to disk instead.
# 24/04/22 13:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_11 in memory.
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 2.0 MiB so far)
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_6 in memory.
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_15 in memory.
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_9 in memory.
# 24/04/22 13:18:00 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:03 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:03 WARN BlockManager: Persisting block rdd_203_19 to disk instead.
# 24/04/22 13:18:03 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:03 WARN BlockManager: Persisting block rdd_203_18 to disk instead.
# 24/04/22 13:18:03 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:03 WARN BlockManager: Persisting block rdd_203_20 to disk instead.
# 24/04/22 13:18:03 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:03 WARN BlockManager: Persisting block rdd_203_16 to disk instead.
# 24/04/22 13:18:05 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 357.9 MiB so far)
# 24/04/22 13:18:05 WARN BlockManager: Persisting block rdd_203_17 to disk instead.
# 24/04/22 13:18:06 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:06 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 8.4 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 238.6 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 3.6 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_18 in memory.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_205_18 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:09 WARN BlockManager: Persisting block rdd_205_18 to disk instead.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_16 in memory.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_205_16 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:09 WARN BlockManager: Persisting block rdd_205_16 to disk instead.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_17 in memory.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_205_17 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:09 WARN BlockManager: Persisting block rdd_205_17 to disk instead.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_19 in memory.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_19 in memory.
# 24/04/22 13:18:09 WARN MemoryStore: Not enough space to cache rdd_205_19 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:09 WARN BlockManager: Persisting block rdd_205_19 to disk instead.
# 24/04/22 13:18:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_18 in memory.
# 24/04/22 13:18:10 WARN MemoryStore: Not enough space to cache rdd_205_18 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_16 in memory.
# 24/04/22 13:18:10 WARN MemoryStore: Not enough space to cache rdd_205_16 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_8 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_15 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_10 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_0 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_1 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_6 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_2 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_3 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_7 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_9 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_4 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_11 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_13 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_12 in memory.
# 24/04/22 13:18:12 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:13 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:13 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:13 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:13 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:13 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_7 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_12 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_13 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_6 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_4 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_14 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_2 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_3 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_11 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_8 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_15 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_10 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_1 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_0 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_9 in memory.
# 24/04/22 13:18:15 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:17 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:17 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:17 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:17 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:17 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_10 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_1 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_11 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_3 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_12 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_2 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_14 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_0 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_7 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_8 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_15 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_4 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_13 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_9 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_6 in memory.
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:18 WARN MemoryStore: Not enough space to cache rdd_205_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_19 in memory.
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_205_19 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_205_18 in memory! (computed 2.0 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_205_20 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_205_17 in memory! (computed 2.0 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:18:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_16 in memory.
# 24/04/22 13:18:20 WARN MemoryStore: Not enough space to cache rdd_205_16 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_14 in memory.
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_5 in memory.
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_2 in memory.
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_10 in memory.
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_205_1 in memory.
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_15 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_3 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_7 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_13 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_8 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_0 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_9 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_12 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:22 WARN MemoryStore: Not enough space to cache rdd_205_4 in memory! (computed 1024.2 KiB so far)
# 24/04/22 13:18:23 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 357.9 MiB so far)
# 24/04/22 13:18:24 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:24 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:24 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:18:24 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:24 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 8.4 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_6 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_3 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_6 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_3 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_0 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_5 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_223_3 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_223_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_223_6 in memory.
# 24/04/22 13:18:25 WARN MemoryStore: Not enough space to cache rdd_223_6 in memory! (computed 384.0 B so far)
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_5 in memory.
# 24/04/22 13:18:25 WARN BlockManager: Persisting block rdd_223_6 to disk instead.
# 24/04/22 13:18:25 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_203_0 in memory.
# ...
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_13 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_1 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_0 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_9 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_8 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_8 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_3 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_2 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_10 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_11 in memory.
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_7 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_6 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_4 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:55 WARN MemoryStore: Not enough space to cache rdd_402_5 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:56 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:21:56 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:21:56 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:21:56 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:21:56 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:21:57 WARN MemoryStore: Not enough space to cache rdd_402_19 in memory! (computed 2.7 MiB so far)
# 24/04/22 13:21:57 WARN MemoryStore: Not enough space to cache rdd_402_20 in memory! (computed 6.2 MiB so far)
# 24/04/22 13:21:57 WARN MemoryStore: Not enough space to cache rdd_402_18 in memory! (computed 2.7 MiB so far)
# 24/04/22 13:21:57 WARN MemoryStore: Not enough space to cache rdd_402_17 in memory! (computed 4.0 MiB so far)
# 24/04/22 13:21:57 WARN MemoryStore: Not enough space to cache rdd_402_16 in memory! (computed 6.2 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_14 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_3 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_9 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_3 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_15 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_15 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_2 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_5 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_5 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_4 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_11 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_7 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_0 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_10 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_12 in memory.
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_8 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_1 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:21:58 WARN MemoryStore: Not enough space to cache rdd_402_13 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 100.6 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_402_19 in memory! (computed 4.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_402_20 in memory! (computed 4.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_402_16 in memory! (computed 4.0 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_402_17 in memory! (computed 2.7 MiB so far)
# 24/04/22 13:22:00 WARN MemoryStore: Not enough space to cache rdd_402_18 in memory! (computed 6.2 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_8 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_13 in memory! (computed 19.1 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_15 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_5 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_6 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_0 in memory! (computed 12.6 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_2 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_7 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_1 in memory! (computed 8.4 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_0 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_0 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_7 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_1 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_1 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_7 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block broadcast_237 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache broadcast_237 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_12 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_2 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_2 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_12 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_12 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_4 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_11 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_4 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_4 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_14 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_14 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_14 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_10 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_10 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_10 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_203_9 in memory! (computed 29.8 MiB so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_9 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_9 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_11 in memory.
# 24/04/22 13:22:02 WARN MemoryStore: Not enough space to cache rdd_402_11 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:03 WARN MemoryStore: Not enough space to cache rdd_203_3 in memory! (computed 357.9 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_203_20 in memory! (computed 44.7 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_203_17 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_203_18 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_402_20 in memory! (computed 1537.3 KiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_203_19 in memory! (computed 67.0 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_19 in memory.
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_402_19 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_402_17 in memory! (computed 1537.3 KiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_203_16 in memory! (computed 150.9 MiB so far)
# 24/04/22 13:22:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_402_16 in memory.
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_402_16 in memory! (computed 384.0 B so far)
# 24/04/22 13:22:04 WARN MemoryStore: Not enough space to cache rdd_402_18 in memory! (computed 1537.3 KiB so far)
# [Stage 162:====================================================>  (20 + 1) / 21]
# Gradient Boosting AUC:  0.6363557826714065

# %%
# Support Vector Machine
svm = LinearSVC(labelCol="numClick", featuresCol="features", maxIter=10)
pipeline_svm = Pipeline(stages=stages + [svm])
model_svm = pipeline_svm.fit(df)
predictions_svm = model_svm.transform(df)
print("SVM AUC: ", evaluator.evaluate(predictions_svm))
# Out:
# 24/04/22 13:23:08 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 31.2 MiB so far)
# 24/04/22 13:23:08 WARN BlockManager: Persisting block rdd_490_15 to disk instead.
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_14 in memory! (computed 31.1 MiB so far)
# 24/04/22 13:23:09 WARN BlockManager: Persisting block rdd_490_14 to disk instead.
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 31.2 MiB so far)
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:09 WARN BlockManager: Persisting block rdd_490_4 to disk instead.
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:09 WARN BlockManager: Persisting block rdd_490_6 to disk instead.
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_3 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:09 WARN BlockManager: Persisting block rdd_490_3 to disk instead.
# 24/04/22 13:23:09 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:11 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:11 WARN BlockManager: Persisting block rdd_490_16 to disk instead.
# 24/04/22 13:23:11 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:11 WARN BlockManager: Persisting block rdd_490_17 to disk instead.
# 24/04/22 13:23:11 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:11 WARN BlockManager: Persisting block rdd_490_20 to disk instead.
# 24/04/22 13:23:11 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:11 WARN BlockManager: Persisting block rdd_490_18 to disk instead.
# 24/04/22 13:23:11 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:14 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:14 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:14 WARN BlockManager: Persisting block rdd_490_19 to disk instead.
# 24/04/22 13:23:14 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:14 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:14 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 33.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:15 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:16 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:17 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_20 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:18 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:19 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:20 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:21 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:22 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:23 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:24 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:25 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:26 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:27 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:28 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_6 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_4 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_15 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_19 in memory! (computed 1024.6 KiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_17 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_18 in memory! (computed 17.0 MiB so far)
# 24/04/22 13:23:29 WARN MemoryStore: Not enough space to cache rdd_490_16 in memory! (computed 17.0 MiB so far)
# SVM AUC:  0.5139024891407198
